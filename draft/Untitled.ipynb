# %%
# this will execute and show the output from
# all code cells of the specified notebook
# %run ./Candida_NLP_word2vec.ipynb ;
# Out:
# hii coconut_nectar and coconut_butter ok to have when treat candida
#
# thank for -PRON- help
#
# not sure about coconut_butter
#
# coconut_nectar would be a definite no because of the high natural sugar_content
#
# 12 training epochs so far.
# CPU times: user 64.5 ms, sys: 14.3 ms, total: 78.7 ms
# Wall time: 72.4 ms
# 12 training epochs so far.
# 9,032 terms in the candi2vec vocabulary.
# matrix shape: (9032, 100)
# Populating the interactive namespace from numpy and matplotlib
# ./Candida_NLP_word2vec.ipynb:13: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   "metadata": {
# /Users/eran/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['figure', 'f', 'show']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ...
