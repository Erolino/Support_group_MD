# %%
if 1==0:  ## ignore this line
    # %run /Users/eran/Galvanize_more_repositories/Support_group_MD/draft/Candida_NLP_pyLDAvis_visualizing-sents.ipynbers/eran/Galvanize_more_repositories/Support_group_MD/draft/Candida_NLP_pyLDAvis_visualizing-sents.ipynb

# %%
with codecs.open(joinp(pilot_path,'ldavis_10'),'rb') as f:  ## used 'rb' cause of this https://github.com/tkipf/gcn/issues/6
    LDAvis_prepared_10 = pickle.load(f)
pyLDAvis.display(LDAvis_prepared_10)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el804571123696525043393382993"></div>
# <script type="text/javascript">
#
# ...
