# %%
if 1==0:
    # %run /Users/eran/Galvanize_more_repositories/Support_group_MD/draft/Candida_NLP_word2vec.ipynb

# %%
show(tsne_plot);
# Out:
#   <div class="bk-root" id="59dfc85b-34cd-4670-a341-9041c6d71ba6"></div>
